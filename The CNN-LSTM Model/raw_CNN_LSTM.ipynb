# %%
import numpy as np
import pandas as pd
import csv
import pickle
import os
import scipy
import gc
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix,accuracy_score
import seaborn as sns
from keras.utils import np_utils
from keras.layers import LSTM, BatchNormalization,Reshape,TimeDistributed
import tensorflow
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# enable gpu
from keras import backend as K
K._get_available_gpus()
# Out:
# ['/device:GPU:0']

# %%
DataPath=  '/content/drive/MyDrive/Colab Notebooks/pattern/lab4/data/RML2016.10b.dat' #'/content/drive/MyDrive/ModulationClassification/RML2016.10b.dat'

# %%
pickle_in = open(DataPath,"rb")
data = pickle.load(pickle_in, encoding="bytes")

# %%
def load_data(data):
  s = np.empty((0,128,2))
  l=np.array([])
  for key in data.keys():
    # load samples
    x,y=key
    x = x.decode('ascii')
    samples = np.array(data.get(key)).transpose(0, 2, 1)
    # create labels
    labels = np.repeat(x+'_'+str(y),samples.shape[0])
    l=np.concatenate([l,labels])
    s=np.vstack((s,samples))
    print('key',key)
    print("samples:",samples.shape)
    print('labels',labels.shape)
  return l,s,data.keys()

# %%
def split_tuple(labels):
  label, snr = map(list, zip(*(x.split('_') for x in labels)))
  label,snr=np.array(label),np.array(snr)
  return label,snr

# %%
def first_drev(data):
  drev = np.empty((0,128,2))
  for i in range(200):
    print(i)
    tmp = np.gradient(data[i*6000:i*6000+6000][:][:],axis=1)
    drev=np.vstack((drev,tmp))
    del tmp
  return drev

# %%
def integral(data):
  data=np.pad(data, [(0, 0),(0,0),(0,1)], 'constant')
  integral = np.empty((0,128,2))
  for i in range(200):
    print(i)
    tmp = scipy.integrate.cumtrapz(data[i*6000:i*6000+6000][:][:],dx=1)
    integral=np.vstack((integral,tmp))
    del tmp
  return integral

# %%
def create_model():
  number_of_channels = 2 
  model = Sequential()
  
  model.add(Conv2D(64, (1,3),padding='same',input_shape=(128, number_of_channels,1), activation='relu'))

  model.add(Conv2D(16, (2,3),padding='same',activation='relu'))

  model.add(BatchNormalization())
  
  model.add(Flatten())
  model.add(Reshape((-1, 16)))
  model.add(LSTM(64))

  model.add(BatchNormalization())

  model.add(Dense(10, activation ='softmax'))


  

  return model

# %%
# get samples and labels
labels, samples,classes = load_data(data)
# Out:
# key (b'QPSK', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 0)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', 4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'BPSK', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', -20)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'CPFSK', -14)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -18)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', 10)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM64', -16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QAM16', 16)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -8)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'AM-DSB', 12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'PAM4', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'QPSK', -4)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', -2)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'GFSK', -12)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'8PSK', 6)
# samples: (6000, 128, 2)
# labels (6000,)
# key (b'WBFM', 12)
# samples: (6000, 128, 2)
# labels (6000,)

# %%
# test drevative
d = np.array(first_drev(samples))
print("drevative:",d.shape)

# %%
# test integration
i = np.array(integral(samples))
print("integral:",i.shape)

# %%
path = '/content/drive/MyDrive/Colab Notebooks/pattern/lab4/integral.npy'
samples = np.load(path)
path = '/content/drive/MyDrive/Colab Notebooks/pattern/lab4/labels.npy'
labels= np.load(path)

# %%
# to encode the labels
lb = LabelEncoder()

# split data into train and test
x_train, x_test, y_train, y_test = train_test_split(samples, labels,test_size=0.3, random_state=1 ,stratify=labels)
del samples
del labels
gc.collect()
# take 5% of training set for validation 
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=0.05, random_state=1,stratify=y_train)

y_train,snr_train = split_tuple(y_train)
y_test,snr_test = split_tuple(y_test)
y_val,snr_val=split_tuple(y_val)

# encode labels
y_train_lb = np_utils.to_categorical(lb.fit_transform(y_train))
y_val_lb = np_utils.to_categorical(lb.fit_transform(y_val))
del y_train
del y_val
gc.collect()
# Out:
# 0

# %%
# create model
model = create_model()
model.compile(loss = 'categorical_crossentropy',optimizer = 'Adam', metrics = ['accuracy'])
# Save an image of the model's architecture to a file
plot_model(model, to_file='Feed Forward NN.png', show_shapes=True, show_layer_names=True)

# %%
model = create_model()
opt = tensorflow.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(loss = 'categorical_crossentropy',optimizer = opt, metrics = ['accuracy'])
path = '/content/drive/MyDrive/Colab Notebooks/pattern/lab4/backup/raw/'
checkpoint_filepath = path+'check_raw'
model_checkpoint_callback = tensorflow.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
# train model
cnn_results = model.fit(x_train, y_train_lb,
                  epochs = 60,
                  batch_size=64,
                  verbose = 1,
                  validation_data = (x_val, y_val_lb),callbacks=[model_checkpoint_callback])
# Plot model accuracy over ephocs
plt.plot(cnn_results.history['accuracy'])
plt.plot(cnn_results.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
gc.collect()
# Out:
# Epoch 1/60
# 12469/12469 [==============================] - 184s 13ms/step - loss: 1.7430 - accuracy: 0.3013 - val_loss: 2.2487 - val_accuracy: 0.2066
# Epoch 2/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.5697 - accuracy: 0.3597 - val_loss: 2.9535 - val_accuracy: 0.2033
# Epoch 3/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.4632 - accuracy: 0.4000 - val_loss: 1.5443 - val_accuracy: 0.3906
# Epoch 4/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.3966 - accuracy: 0.4237 - val_loss: 1.4585 - val_accuracy: 0.4014
# Epoch 5/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.3573 - accuracy: 0.4363 - val_loss: 1.3226 - val_accuracy: 0.4500
# Epoch 6/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.3315 - accuracy: 0.4471 - val_loss: 1.3296 - val_accuracy: 0.4496
# Epoch 7/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.2997 - accuracy: 0.4609 - val_loss: 1.3142 - val_accuracy: 0.4560
# Epoch 8/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.2533 - accuracy: 0.4779 - val_loss: 1.4100 - val_accuracy: 0.4396
# Epoch 9/60
# 12469/12469 [==============================] - 171s 14ms/step - loss: 1.2381 - accuracy: 0.4837 - val_loss: 1.1952 - val_accuracy: 0.4968
# Epoch 10/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.2089 - accuracy: 0.4931 - val_loss: 1.5444 - val_accuracy: 0.4233
# Epoch 11/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.1810 - accuracy: 0.5037 - val_loss: 1.1749 - val_accuracy: 0.5038
# Epoch 12/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.1633 - accuracy: 0.5105 - val_loss: 1.1775 - val_accuracy: 0.5061
# Epoch 13/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.1530 - accuracy: 0.5140 - val_loss: 1.1844 - val_accuracy: 0.5066
# Epoch 14/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.1437 - accuracy: 0.5172 - val_loss: 1.1905 - val_accuracy: 0.5062
# Epoch 15/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.1319 - accuracy: 0.5215 - val_loss: 1.3265 - val_accuracy: 0.4615
# Epoch 16/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.1232 - accuracy: 0.5254 - val_loss: 1.1038 - val_accuracy: 0.5298
# Epoch 17/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.1229 - accuracy: 0.5257 - val_loss: 1.1665 - val_accuracy: 0.5157
# Epoch 18/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.1118 - accuracy: 0.5306 - val_loss: 1.0966 - val_accuracy: 0.5358
# Epoch 19/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.1118 - accuracy: 0.5311 - val_loss: 1.1083 - val_accuracy: 0.5339
# Epoch 20/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.1031 - accuracy: 0.5357 - val_loss: 1.0890 - val_accuracy: 0.5400
# Epoch 21/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.1000 - accuracy: 0.5370 - val_loss: 1.1413 - val_accuracy: 0.5330
# Epoch 22/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0962 - accuracy: 0.5393 - val_loss: 1.1035 - val_accuracy: 0.5363
# Epoch 23/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0976 - accuracy: 0.5382 - val_loss: 1.0959 - val_accuracy: 0.5364
# Epoch 24/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0921 - accuracy: 0.5398 - val_loss: 1.0803 - val_accuracy: 0.5434
# Epoch 25/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0890 - accuracy: 0.5414 - val_loss: 1.0711 - val_accuracy: 0.5499
# Epoch 26/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.0852 - accuracy: 0.5439 - val_loss: 1.1073 - val_accuracy: 0.5300
# Epoch 27/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0821 - accuracy: 0.5454 - val_loss: 1.0707 - val_accuracy: 0.5491
# Epoch 28/60
# 12469/12469 [==============================] - 168s 14ms/step - loss: 1.0860 - accuracy: 0.5431 - val_loss: 1.1042 - val_accuracy: 0.5435
# Epoch 29/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0785 - accuracy: 0.5463 - val_loss: 1.0670 - val_accuracy: 0.5519
# Epoch 30/60
# 12469/12469 [==============================] - 166s 13ms/step - loss: 1.0893 - accuracy: 0.5418 - val_loss: 1.1100 - val_accuracy: 0.5310
# Epoch 31/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0742 - accuracy: 0.5478 - val_loss: 1.1353 - val_accuracy: 0.5394
# Epoch 32/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0741 - accuracy: 0.5470 - val_loss: 1.0642 - val_accuracy: 0.5546
# Epoch 33/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0702 - accuracy: 0.5493 - val_loss: 1.0754 - val_accuracy: 0.5509
# Epoch 34/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0666 - accuracy: 0.5515 - val_loss: 1.0622 - val_accuracy: 0.5513
# Epoch 35/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0688 - accuracy: 0.5506 - val_loss: 1.1908 - val_accuracy: 0.5119
# Epoch 36/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0677 - accuracy: 0.5505 - val_loss: 1.0466 - val_accuracy: 0.5601
# Epoch 37/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0673 - accuracy: 0.5502 - val_loss: 1.0640 - val_accuracy: 0.5524
# Epoch 38/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0648 - accuracy: 0.5519 - val_loss: 1.0664 - val_accuracy: 0.5529
# Epoch 39/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0592 - accuracy: 0.5543 - val_loss: 1.0666 - val_accuracy: 0.5504
# Epoch 40/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0572 - accuracy: 0.5550 - val_loss: 1.0593 - val_accuracy: 0.5540
# Epoch 41/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0555 - accuracy: 0.5557 - val_loss: 1.0879 - val_accuracy: 0.5439
# Epoch 42/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0573 - accuracy: 0.5544 - val_loss: 1.0624 - val_accuracy: 0.5531
# Epoch 43/60
# 12469/12469 [==============================] - 168s 14ms/step - loss: 1.0523 - accuracy: 0.5574 - val_loss: 1.0392 - val_accuracy: 0.5582
# Epoch 44/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0550 - accuracy: 0.5558 - val_loss: 1.0738 - val_accuracy: 0.5429
# Epoch 45/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.0572 - accuracy: 0.5557 - val_loss: 1.0494 - val_accuracy: 0.5576
# Epoch 46/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0483 - accuracy: 0.5586 - val_loss: 1.0583 - val_accuracy: 0.5528
# Epoch 47/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0537 - accuracy: 0.5564 - val_loss: 1.0663 - val_accuracy: 0.5534
# Epoch 48/60
# 12469/12469 [==============================] - 168s 14ms/step - loss: 1.0439 - accuracy: 0.5599 - val_loss: 1.0470 - val_accuracy: 0.5592
# Epoch 49/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0530 - accuracy: 0.5544 - val_loss: 1.0415 - val_accuracy: 0.5605
# Epoch 50/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0417 - accuracy: 0.5604 - val_loss: 1.0435 - val_accuracy: 0.5609
# Epoch 51/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0465 - accuracy: 0.5583 - val_loss: 1.0509 - val_accuracy: 0.5585
# Epoch 52/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0385 - accuracy: 0.5623 - val_loss: 1.0282 - val_accuracy: 0.5707
# Epoch 53/60
# 12469/12469 [==============================] - 167s 13ms/step - loss: 1.0366 - accuracy: 0.5629 - val_loss: 1.0372 - val_accuracy: 0.5634
# Epoch 54/60
# 12469/12469 [==============================] - 168s 13ms/step - loss: 1.0424 - accuracy: 0.5602 - val_loss: 1.0372 - val_accuracy: 0.5564
# Epoch 55/60
# 12469/12469 [==============================] - 174s 14ms/step - loss: 1.0310 - accuracy: 0.5647 - val_loss: 1.0343 - val_accuracy: 0.5659
# Epoch 56/60
# 12469/12469 [==============================] - 170s 14ms/step - loss: 1.0311 - accuracy: 0.5654 - val_loss: 1.0495 - val_accuracy: 0.5591
# Epoch 57/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0306 - accuracy: 0.5653 - val_loss: 1.0396 - val_accuracy: 0.5625
# Epoch 58/60
# 12469/12469 [==============================] - 175s 14ms/step - loss: 1.0260 - accuracy: 0.5674 - val_loss: 1.0345 - val_accuracy: 0.5657
# Epoch 59/60
# 12469/12469 [==============================] - 170s 14ms/step - loss: 1.0253 - accuracy: 0.5677 - val_loss: 1.0406 - val_accuracy: 0.5626
# Epoch 60/60
# 12469/12469 [==============================] - 169s 14ms/step - loss: 1.0233 - accuracy: 0.5682 - val_loss: 1.0200 - val_accuracy: 0.5711
# 7885

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/pattern/lab4/data/raw_bonus.h5')

# %%
# Plot model loss over ephocs
plt.plot(cnn_results.history['loss'])
plt.plot(cnn_results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
del x_train
del y_train_lb
del x_val
del y_val_lb
gc.collect()
# Out:
# 3040

# %%
# evaluate test set
# encode labels
y_test_lb = np_utils.to_categorical(lb.fit_transform(y_test))

score = model.evaluate(x_test, y_test_lb, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Testing Accuracy:  0.5696027874946594

# %%
# to get confusion matrix
y_test_classes = y_test_lb.argmax(1)
y_predicted = model.predict(x_test)
y_pred_classes = np.argmax(y_predicted,axis=1)

# %%
classes = np.load('/content/drive/MyDrive/Colab Notebooks/pattern/lab4/classes.npy')

# %%
# get confusion matrix
confusion_matrix1 = confusion_matrix(y_true= y_test_classes, y_pred=y_pred_classes)
classes = np.array([x[0] for x in classes])
classes=np.unique(classes)
print(classes)
#Add labels to confusion matrix
confusion_matrix1 = pd.DataFrame(confusion_matrix1, columns=list(classes), index=list(classes))

print("The rows represents the true values or observations")
print("The columns respresent the model's predictions")

#Print confusion matrix results
confusion_matrix1
# Out:
# [b'8PSK' b'AM-DSB' b'BPSK' b'CPFSK' b'GFSK' b'PAM4' b'QAM16' b'QAM64'
#  b'QPSK' b'WBFM']
# The rows represents the true values or observations
# The columns respresent the model's predictions
#            b'8PSK'  b'AM-DSB'  b'BPSK'  b'CPFSK'  b'GFSK'  b'PAM4'  b'QAM16'  \
# b'8PSK'      25336        413      616      2168      848      371       915
# b'AM-DSB'     4041      24046      345       791     1218      162        21
# b'BPSK'       6682        419    22053      1591      795     1461       237
# b'CPFSK'      6580        394      520     23627     1279      308       167
# b'GFSK'       5279        587      399      2163    24698      224        52
# b'PAM4'       4846        329     1935      1282      605    24737       182
# b'QAM16'      5663        206      521      1568      595      336      4600
# b'QAM64'      3869        142      374      1294      420      309      3702
# b'QPSK'       9268        391      657      2186      917      400       616
# b'WBFM'       4060      15343      356       937     2174      154        30
#
#            b'QAM64'  b'QPSK'  b'WBFM'
# b'8PSK'         723     3939      671
# b'AM-DSB'        17      977     4382
# b'BPSK'         252     1839      671
# b'CPFSK'        238     2127      760
# b'GFSK'          39     1239     1320
# b'PAM4'         351     1225      508
# b'QAM16'      20009     2079      423
# b'QAM64'      23965     1646      279
# b'QPSK'         787    20119      659
# b'WBFM'          16     1054    11876

# %%
# get most confusing classes
fig, ax = plt.subplots(figsize=(15,10))         # Sample figsize in inches
sns.heatmap(confusion_matrix1, annot=True, linewidths=.5, ax=ax, fmt='g')

# %%
# Print f1, precision, and recall scores
print("Percision: ",precision_score(y_test_classes, y_pred_classes , average="macro"))
print("Recall: ",recall_score(y_test_classes, y_pred_classes , average="macro"))
print("F-score: ",f1_score(y_test_classes, y_pred_classes , average="macro"))
# Out:
# Percision:  0.5991327459203615
# Recall:  0.5696027777777777
# F-score:  0.5628819483642363

# %%
# group by snr
snr_test = [int(snr) for snr in snr_test]
sorted_snrs = np.sort(np.unique(snr_test))
x = []
y = []
for snr in sorted_snrs:
  idx = np.where(snr_test == snr)
  x.append(snr)
  y.append(accuracy_score(np.argmax(y_test_lb[idx], axis = 1), np.argmax(y_predicted[idx], axis = 1)))

# %%
# print results of snr
pd.DataFrame(data = np.array(y).reshape(1, -1) * 100,  columns = sorted_snrs, index = ['accuracy']).round(2)
# Out:
#             -20    -18    -16    -14    -12    -10    -8     -6     -4   \
# accuracy  10.69  10.86  12.26  14.63  19.59  27.43  36.75  49.53  62.71
#
#             -2      0      2      4      6      8      10     12     14  \
# accuracy  70.21  76.94  80.69  82.62  83.32  83.44  83.77  83.33  83.43
#
#              16     18
# accuracy  83.61  83.39

# %%
# plot accuracy vs snr
plt.xlabel('SNR')
plt.ylabel('Accuracy')
plt.title('Classification Accuracy over different SNRs')
plt.plot(x, np.array(y) * 100, 'bo-')
plt.grid(True)
